# %%
import pandas as pd

df = pd.read_csv("0.1_ENEM_2019.csv",sep=";",encoding = "ISO-8859-1")

df.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  190001692717    2019                  4323804               Xangri-lá
# 1  190001425177    2019                  2927408                Salvador
# 2  190001493204    2019                  2610707                Paulista
# 3  190001237835    2019                  3136702            Juiz de Fora
# 4  190001210217    2019                  2103802               Dom Pedro
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                43               RS      27.0       F                0
# 1                29               BA      18.0       F                1
# 2                26               PE      41.0       F                2
# 3                31               MG      20.0       F                1
# 4                21               MA      18.0       F                3
#
#    TP_COR_RACA  ...  Q016  Q017 Q018  Q019 Q020  Q021  Q022  Q023  Q024  Q025
# ...

# %%
import dask
import dask.dataframe as dd

dfBig = dd.read_csv("MICRODADOS_ENEM_2019.csv",sep=";",encoding = "ISO-8859-1",dtype={'NU_IDADE': 'float64'})

dfBig.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-b02ba0462768> in <module>
#       2 import dask.dataframe as dd
#       3
# ----> 4 dfBig = dd.read_csv("MICRODADOS_ENEM_2019.csv", percentiles=None, percentiles_method='default', include=None, exclude=None,sep=";",encoding = "ISO-8859-1",dtype={'NU_IDADE': 'float64'})
#       5
#       6 dfBig.head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\dask\dataframe\io\csv.py in read(urlpath, blocksize, lineterminator, compression, sample, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     650         **kwargs,
#     651     ):
# --> 652         return read_pandas(
#     653             reader,
#     654             urlpath,
#
# ...

# %%
dfBig.columns
# Out:
# Index(['NU_INSCRICAO', 'NU_ANO', 'CO_MUNICIPIO_RESIDENCIA',
#        'NO_MUNICIPIO_RESIDENCIA', 'CO_UF_RESIDENCIA', 'SG_UF_RESIDENCIA',
#        'NU_IDADE', 'TP_SEXO', 'TP_ESTADO_CIVIL', 'TP_COR_RACA',
#        ...
#        'Q016', 'Q017', 'Q018', 'Q019', 'Q020', 'Q021', 'Q022', 'Q023', 'Q024',
#        'Q025'],
#       dtype='object', length=136)

# %%
#dfBig.info

meuArquivo = open('file.txt', 'w')
meuArquivo.write(str(dfBig.describe(include='all')))
meuArquivo.close()

df.describe(include='all')
# Out:
#         NU_INSCRICAO   NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# count   5.012800e+04  50128.0             5.012800e+04
# unique           NaN      NaN                      NaN
# top              NaN      NaN                      NaN
# freq             NaN      NaN                      NaN
# mean    1.900035e+11   2019.0             3.085745e+06
# std     1.473792e+06      0.0             9.926453e+05
# min     1.900010e+11   2019.0             1.100015e+06
# 25%     1.900023e+11   2019.0             2.407401e+06
# 50%     1.900035e+11   2019.0             3.124154e+06
# 75%     1.900048e+11   2019.0             3.549805e+06
# max     1.900061e+11   2019.0             5.300108e+06
#
#        NO_MUNICIPIO_RESIDENCIA  CO_UF_RESIDENCIA SG_UF_RESIDENCIA  \
# count                    50128      50128.000000            50128
# unique                    4151               NaN               27
# top                  São Paulo               NaN               SP
# ...
